# %% [markdown]
# # MCP Server & Client Implementation Using Fastmcp
#
# ---
# ## Architecture
#
# LLM Host (MCP Client)  <—— JSON-RPC ——>  fastmcp Server  <——> CSV Dataset
#
#
# We'll:
# 1. Launch a server exposing two tools (`summarize`, `query`).
# 2. Use an MCP Client to discover and call those tools.
# 3. Simulate a host (agent) deciding which tool to call.
# ---
# ## Start the MCP Server
#
# In a separate terminal, run:
# ```bash
# python mcp_server_fastmcp.py
# ```
# This starts an MCP-compliant server exposing `summarize` and `query` tools.
#
# ---

# %% [markdown]
# ### 1. Install dependencies

# %%
# %pip install fastmcp pandas openai 
# uvicorn --upgrade --no-cache-dir
# Out:
# Requirement already satisfied: fastmcp in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (2.14.5)
# Requirement already satisfied: pandas in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (3.0.0)
# Requirement already satisfied: openai in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (2.17.0)
# Requirement already satisfied: authlib>=1.6.5 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (1.6.7)
# Requirement already satisfied: cyclopts>=4.0.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (4.5.1)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (1.3.1)
# Requirement already satisfied: httpx>=0.28.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (0.28.1)
# Requirement already satisfied: jsonref>=1.1.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (1.1.0)
# Requirement already satisfied: jsonschema-path>=0.3.4 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (0.3.4)
# Requirement already satisfied: mcp<2.0,>=1.24.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (1.26.0)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (0.5.1)
# Requirement already satisfied: packaging>=20.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (25.0)
# Requirement already satisfied: platformdirs>=4.0.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (4.5.1)
# Requirement already satisfied: py-key-value-aio<0.4.0,>=0.3.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.3.0)
# Requirement already satisfied: pydantic>=2.11.7 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.12.5)
# Requirement already satisfied: pydocket>=0.17.2 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (0.17.5)
# Requirement already satisfied: pyperclip>=1.9.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (1.11.0)
# Requirement already satisfied: python-dotenv>=1.1.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (1.2.1)
# Requirement already satisfied: rich>=13.9.4 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (14.3.1)
# Requirement already satisfied: uvicorn>=0.35 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (0.40.0)
# Requirement already satisfied: websockets>=15.0.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fastmcp) (16.0)
# Requirement already satisfied: anyio>=4.5 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0,>=1.24.0->fastmcp) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (0.52.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (0.4.2)
# Requirement already satisfied: py-key-value-shared==0.3.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from py-key-value-aio<0.4.0,>=0.3.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.3.0)
# Requirement already satisfied: beartype>=0.20.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from py-key-value-aio<0.4.0,>=0.3.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.22.9)
# Requirement already satisfied: diskcache>=5.0.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (5.6.3)
# Requirement already satisfied: pathvalidate>=3.3.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (3.3.1)
# Requirement already satisfied: keyring>=25.6.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (25.7.0)
# Requirement already satisfied: cachetools>=5.0.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (6.2.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (2.41.5)
# Requirement already satisfied: numpy>=1.26.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from openai) (0.11.1)
# Requirement already satisfied: sniffio in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: idna>=2.8 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from anyio>=4.5->mcp<2.0,>=1.24.0->fastmcp) (3.11)
# Requirement already satisfied: certifi in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from httpx>=0.28.1->fastmcp) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from httpx>=0.28.1->fastmcp) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp) (0.16.0)
# Requirement already satisfied: cryptography in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from authlib>=1.6.5->fastmcp) (46.0.4)
# Requirement already satisfied: attrs>=23.1.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from cyclopts>=4.0.0->fastmcp) (25.4.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from cyclopts>=4.0.0->fastmcp) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from cyclopts>=4.0.0->fastmcp) (1.3.2)
# Requirement already satisfied: docutils in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->fastmcp) (0.22.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp) (0.36.2)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp) (0.30.0)
# Requirement already satisfied: PyYAML>=5.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from jsonschema-path>=0.3.4->fastmcp) (6.0.3)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from jsonschema-path>=0.3.4->fastmcp) (0.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from jsonschema-path>=0.3.4->fastmcp) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path>=0.3.4->fastmcp) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path>=0.3.4->fastmcp) (2.6.3)
# Requirement already satisfied: jaraco.classes in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (3.4.0)
# Requirement already satisfied: jaraco.functools in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (4.4.0)
# Requirement already satisfied: jaraco.context in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (6.1.0)
# Requirement already satisfied: email-validator>=2.0.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp) (2.8.0)
# Requirement already satisfied: cloudpickle>=3.1.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydocket>=0.17.2->fastmcp) (3.1.2)
# Requirement already satisfied: croniter>=6 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydocket>=0.17.2->fastmcp) (6.0.0)
# Requirement already satisfied: fakeredis>=2.32.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fakeredis[lua]>=2.32.1->pydocket>=0.17.2->fastmcp) (2.33.0)
# Requirement already satisfied: opentelemetry-api>=1.33.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydocket>=0.17.2->fastmcp) (1.39.1)
# Requirement already satisfied: prometheus-client>=0.21.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydocket>=0.17.2->fastmcp) (0.24.1)
# Requirement already satisfied: python-json-logger>=2.0.7 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydocket>=0.17.2->fastmcp) (4.0.0)
# Requirement already satisfied: redis>=5 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydocket>=0.17.2->fastmcp) (7.1.0)
# Requirement already satisfied: typer>=0.15.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from pydocket>=0.17.2->fastmcp) (0.21.1)
# Requirement already satisfied: pytz>2021.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from croniter>=6->pydocket>=0.17.2->fastmcp) (2025.2)
# Requirement already satisfied: sortedcontainers>=2 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fakeredis>=2.32.1->fakeredis[lua]>=2.32.1->pydocket>=0.17.2->fastmcp) (2.4.0)
# Requirement already satisfied: lupa>=2.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from fakeredis[lua]>=2.32.1->pydocket>=0.17.2->fastmcp) (2.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from opentelemetry-api>=1.33.0->pydocket>=0.17.2->fastmcp) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.33.0->pydocket>=0.17.2->fastmcp) (3.23.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from cryptography->authlib>=1.6.5->fastmcp) (2.0.0)
# Requirement already satisfied: pycparser in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography->authlib>=1.6.5->fastmcp) (3.0)
# Requirement already satisfied: six>=1.5 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from rich>=13.9.4->fastmcp) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from rich>=13.9.4->fastmcp) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp) (0.1.2)
# Requirement already satisfied: click>=8.0.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from typer>=0.15.1->pydocket>=0.17.2->fastmcp) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from typer>=0.15.1->pydocket>=0.17.2->fastmcp) (1.5.4)
# Requirement already satisfied: more-itertools in /Users/amiteshsinha/Training/2026_1_GenAI_Lab/.venv/lib/python3.13/site-packages (from jaraco.classes->keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (10.8.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Connect via MCP Client
#
# Once the server is running, connect using the MCP client to list tools and invoke them.

# %%
from fastmcp import Client
from fastmcp.client import PythonStdioTransport
import asyncio

async def main():
    # Create a client using the PythonStdioTransport
    # Create a loop to run the client

    transport = PythonStdioTransport("mcp_server_fastmcp.py")
    
    # client = Client(transport)

    async with Client(transport) as client:
        tools = await client.list_tools()
        print("Tools:", [t.name for t in tools])

await main()
# Out:
# Tools: ['summarize', 'abc', 'query']

# %% [markdown]
# ## Simulate a Simple Host Agent
# Let's simulate a rule-based 'AI agent' that decides whether to use `summarize` or `query` based on user text.

# %%
def decide_tool(text: str):
    text = text.lower()
    if "summarize" in text or "overview" in text:
        return "summarize", {}
    if "west" in text:
        return "query", {"expr": "region == 'West'"}
    return "summarize", {}

async def run_agent(user_input, client):
    tool, params = decide_tool(user_input) #"summarize", {}
    #tool = "summarize"
    #params = {}
    print(f"Agent decided to use '{tool}'")

    # API for fastmcp 2.12.5
    result = await client.call_tool(tool, params)
    # result = await client.call_tool("query", params)

    print("Result:", result, "\n")

# %%
# create a connection to your MCP server
transport = PythonStdioTransport("mcp_server_fastmcp.py")

async with Client(transport) as client:
    await run_agent("Give me a summary of the dataset", client)
# Out:
# Agent decided to use 'summarize'
# Result: CallToolResult(content=[TextContent(type='text', text='{"rows":10,"columns":["order_id","region","sales","quarter","rep"],"numeric_stats":{"order_id":{"count":10.0,"unique":"","top":"","freq":"","mean":105.5,"std":3.0276503540974917,"min":101.0,"25%":103.25,"50%":105.5,"75%":107.75,"max":110.0},"region":{"count":10,"unique":4,"top":"West","freq":4,"mean":"","std":"","min":"","25%":"","50%":"","75%":"","max":""},"sales":{"count":10.0,"unique":"","top":"","freq":"","mean":1235.0,"std":536.4751210965477,"min":600.0,"25%":825.0,"50%":1175.0,"75%":1450.0,"max":2200.0},"quarter":{"count":10,"unique":4,"top":"Q1","freq":3,"mean":"","std":"","min":"","25%":"","50%":"","75%":"","max":""},"rep":{"count":10,"unique":10,"top":"Alex","freq":1,"mean":"","std":"","min":"","25%":"","50%":"","75%":"","max":""}}}', annotations=None, meta=None)], structured_content={'rows': 10, 'columns': ['order_id', 'region', 'sales', 'quarter', 'rep'], 'numeric_stats': {'order_id': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 105.5, 'std': 3.0276503540974917, 'min': 101.0, '25%': 103.25, '50%': 105.5, '75%': 107.75, 'max': 110.0}, 'region': {'count': 10, 'unique': 4, 'top': 'West', 'freq': 4, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'sales': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 1235.0, 'std': 536.4751210965477, 'min': 600.0, '25%': 825.0, '50%': 1175.0, '75%': 1450.0, 'max': 2200.0}, 'quarter': {'count': 10, 'unique': 4, 'top': 'Q1', 'freq': 3, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'rep': {'count': 10, 'unique': 10, 'top': 'Alex', 'freq': 1, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}}}, meta=None, data={'rows': 10, 'columns': ['order_id', 'region', 'sales', 'quarter', 'rep'], 'numeric_stats': {'order_id': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 105.5, 'std': 3.0276503540974917, 'min': 101.0, '25%': 103.25, '50%': 105.5, '75%': 107.75, 'max': 110.0}, 'region': {'count': 10, 'unique': 4, 'top': 'West', 'freq': 4, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'sales': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 1235.0, 'std': 536.4751210965477, 'min': 600.0, '25%': 825.0, '50%': 1175.0, '75%': 1450.0, 'max': 2200.0}, 'quarter': {'count': 10, 'unique': 4, 'top': 'Q1', 'freq': 3, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'rep': {'count': 10, 'unique': 10, 'top': 'Alex', 'freq': 1, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}}}, is_error=False)

# %%
# create a connection to your MCP server
transport = PythonStdioTransport("mcp_server_fastmcp.py")

async with Client(transport) as client:
    await run_agent("Give me a summary of the dataset", client)
    await run_agent("Show West region sales > 1500", client)
# Out:
# Agent decided to use 'summarize'
# Result: CallToolResult(content=[TextContent(type='text', text='{"rows":10,"columns":["order_id","region","sales","quarter","rep"],"numeric_stats":{"order_id":{"count":10.0,"unique":"","top":"","freq":"","mean":105.5,"std":3.0276503540974917,"min":101.0,"25%":103.25,"50%":105.5,"75%":107.75,"max":110.0},"region":{"count":10,"unique":4,"top":"West","freq":4,"mean":"","std":"","min":"","25%":"","50%":"","75%":"","max":""},"sales":{"count":10.0,"unique":"","top":"","freq":"","mean":1235.0,"std":536.4751210965477,"min":600.0,"25%":825.0,"50%":1175.0,"75%":1450.0,"max":2200.0},"quarter":{"count":10,"unique":4,"top":"Q1","freq":3,"mean":"","std":"","min":"","25%":"","50%":"","75%":"","max":""},"rep":{"count":10,"unique":10,"top":"Alex","freq":1,"mean":"","std":"","min":"","25%":"","50%":"","75%":"","max":""}}}', annotations=None, meta=None)], structured_content={'rows': 10, 'columns': ['order_id', 'region', 'sales', 'quarter', 'rep'], 'numeric_stats': {'order_id': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 105.5, 'std': 3.0276503540974917, 'min': 101.0, '25%': 103.25, '50%': 105.5, '75%': 107.75, 'max': 110.0}, 'region': {'count': 10, 'unique': 4, 'top': 'West', 'freq': 4, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'sales': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 1235.0, 'std': 536.4751210965477, 'min': 600.0, '25%': 825.0, '50%': 1175.0, '75%': 1450.0, 'max': 2200.0}, 'quarter': {'count': 10, 'unique': 4, 'top': 'Q1', 'freq': 3, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'rep': {'count': 10, 'unique': 10, 'top': 'Alex', 'freq': 1, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}}}, meta=None, data={'rows': 10, 'columns': ['order_id', 'region', 'sales', 'quarter', 'rep'], 'numeric_stats': {'order_id': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 105.5, 'std': 3.0276503540974917, 'min': 101.0, '25%': 103.25, '50%': 105.5, '75%': 107.75, 'max': 110.0}, 'region': {'count': 10, 'unique': 4, 'top': 'West', 'freq': 4, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'sales': {'count': 10.0, 'unique': '', 'top': '', 'freq': '', 'mean': 1235.0, 'std': 536.4751210965477, 'min': 600.0, '25%': 825.0, '50%': 1175.0, '75%': 1450.0, 'max': 2200.0}, 'quarter': {'count': 10, 'unique': 4, 'top': 'Q1', 'freq': 3, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}, 'rep': {'count': 10, 'unique': 10, 'top': 'Alex', 'freq': 1, 'mean': '', 'std': '', 'min': '', '25%': '', '50%': '', '75%': '', 'max': ''}}}, is_error=False)
#
# Agent decided to use 'query'
# Result: CallToolResult(content=[TextContent(type='text', text='{"count":2,"rows":[{"order_id":107,"region":"West","sales":2000,"quarter":"Q3","rep":"Gale"},{"order_id":110,"region":"West","sales":2200,"quarter":"Q4","rep":"Jules"}]}', annotations=None, meta=None)], structured_content={'count': 2, 'rows': [{'order_id': 107, 'region': 'West', 'sales': 2000, 'quarter': 'Q3', 'rep': 'Gale'}, {'order_id': 110, 'region': 'West', 'sales': 2200, 'quarter': 'Q4', 'rep': 'Jules'}]}, meta=None, data={'count': 2, 'rows': [{'order_id': 107, 'region': 'West', 'sales': 2000, 'quarter': 'Q3', 'rep': 'Gale'}, {'order_id': 110, 'region': 'West', 'sales': 2200, 'quarter': 'Q4', 'rep': 'Jules'}]}, is_error=False)

# %% [markdown]
# ---
# ##  Architecture Recap
# ```
# +--------------------+      JSON-RPC (MCP)      +--------------------+
# |  Host / AI Agent   |  <-------------------->  | fastmcp MCP Server |
# | (LLM or Router)    |                        | (summarize, query)  |
# +--------------------+                         +--------------------+
# ```
# ---
