# %% [markdown]
# ### Print My name is Mark and I got 95

# %%
name = "Mark"
score = 95

print (f"My name is {name}")
print (f"My name is {name} and I got {score}")

# %%
question = input("What is your question? ")
print (f"Your question is: {question}")
