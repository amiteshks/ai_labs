# %% [markdown]
# # Session 1 Code
#
# This is my first interactive python notebook

# %%
print ("Hello AI World!")
a = 5
b = 6

# %%
sum = a + b
print ("The sum of a and b is: ", sum)

# %%
a = 5
print(a)
is_new = True #true
