# %%
system_message = {"role": "system", 
 "content": "You are a educational assistant. Respond as a JSON object with the following keys: response, tokens_count, response_time."}

user_message = {"role": "user", 
 "content": "Where is the Eiffel Tower located?"}


# JSON
# Key Value Pairs 

response_key = 'response'
response_json = {response_key: 'The Eiffel Tower is located in Paris, France.',
                 'tokens_count': 10,
                 'response_time': '0.5 seconds'}

# %%
#response_json[key]
response = 'response'
response_json[response]

# response_json['cost']
response_json.get('cost', 'Key not found')
# Out:
# 'Key not found'
