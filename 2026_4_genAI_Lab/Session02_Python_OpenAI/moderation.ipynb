# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")

print ( my_api_key[-10:])
# Out:
# R_tmR1CcUA

# %%
client = OpenAI(api_key=my_api_key)
question = input("What is your question? ")

# %%
# Step 1: Run moderation check
mod_result = client.moderations.create(
    model="omni-moderation-latest",
    input=question
)

print(f"Moderation result: {mod_result}")
print(f"mod_result.results[0].flagged result: {mod_result.results[0].flagged}")
# Out:
# Moderation result: ModerationCreateResponse(id='modr-168', model='omni-moderation-latest', results=[Moderation(categories=Categories(harassment=False, harassment_threatening=False, hate=False, hate_threatening=False, illicit=False, illicit_violent=False, self_harm=False, self_harm_instructions=False, self_harm_intent=False, sexual=False, sexual_minors=False, violence=True, violence_graphic=False, harassment/threatening=False, hate/threatening=False, illicit/violent=False, self-harm/intent=False, self-harm/instructions=False, self-harm=False, sexual/minors=False, violence/graphic=False), category_applied_input_types=CategoryAppliedInputTypes(harassment=['text'], harassment_threatening=['text'], hate=['text'], hate_threatening=['text'], illicit=['text'], illicit_violent=['text'], self_harm=['text'], self_harm_instructions=['text'], self_harm_intent=['text'], sexual=['text'], sexual_minors=['text'], violence=['text'], violence_graphic=['text'], harassment/threatening=['text'], hate/threatening=['text'], illicit/violent=['text'], self-harm/intent=['text'], self-harm/instructions=['text'], self-harm=['text'], sexual/minors=['text'], violence/graphic=['text']), category_scores=CategoryScores(harassment=0.025958966742600866, harassment_threatening=0.006595774440231681, hate=0.001295188511730922, hate_threatening=2.0027376671813928e-05, illicit=0.019508576265556465, illicit_violent=0.0015829566691024483, self_harm=0.0005809901648210263, self_harm_instructions=0.00022342942504316508, self_harm_intent=0.00026239380687440516, sexual=2.653023768982879e-05, sexual_minors=4.53978687024344e-06, violence=0.20208489837955074, violence_graphic=0.0024116611132049036, harassment/threatening=0.006595774440231681, hate/threatening=2.0027376671813928e-05, illicit/violent=0.0015829566691024483, self-harm/intent=0.00026239380687440516, self-harm/instructions=0.00022342942504316508, self-harm=0.0005809901648210263, sexual/minors=4.53978687024344e-06, violence/graphic=0.0024116611132049036), flagged=True)])
# mod_result.results[0].flagged result: True

# %%
from prompt_toolkit import prompt


client = OpenAI()
while (True):
    question = input("What is your question? ")
    print("You asked: " + question)


    if question.lower() == "exit":
        print("Goodbye!")
        break
    else:
        
        # Step 1: Run moderation check
        mod_result = client.moderations.create(
            model="omni-moderation-latest",
            input=question
        )

        print(f"Moderation result: {mod_result}")
        print(f"mod_result.results[0].flagged result: {mod_result.results[0].flagged}")

        # Step 2: Generate response if not flagged
        if (mod_result.results[0].flagged):
                print("The content of the question is flagged by moderation. Please ask a different question.")
                continue
        else:
            response = client.chat.completions.create(
                model="gpt-4.1-nano", #gpt-5-mini
                messages=[
                    {"role": "system", "content": '''You are an AI assistant. 
                            Please answer the question as best as you can. 
                            If you don't know the answer, say you don't know.'''},
                    {"role": "user", "content": question}
                ]
            )
            text_answer = response.choices[0].message.content
            print (text_answer)
# Out:
# You asked: exit
# Goodbye!
