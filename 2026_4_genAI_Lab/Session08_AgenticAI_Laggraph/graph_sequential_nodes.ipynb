# %%
# python -m venv .venv
# source .venv/bin/activate  # On Windows, use `.venv\Scripts\activate`
# %pip install langgraph
# Out:
# Collecting langgraph
#   Downloading langgraph-1.2.2-py3-none-any.whl.metadata (8.0 kB)
# Collecting langchain-core<2,>=1.4.0 (from langgraph)
#   Downloading langchain_core-1.4.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph)
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph)
#   Downloading langgraph_sdk-0.3.15-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from langgraph) (2.13.3)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Downloading xxhash-3.7.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2,>=1.4.0->langgraph)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.14 (from langchain-core<2,>=1.4.0->langgraph)
#   Downloading langchain_protocol-0.0.16-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2,>=1.4.0->langgraph)
#   Downloading langsmith-0.8.7-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from langchain-core<2,>=1.4.0->langgraph) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from langchain-core<2,>=1.4.0->langgraph) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2,>=1.4.0->langgraph)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from langchain-core<2,>=1.4.0->langgraph) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2,>=1.4.0->langgraph)
#   Downloading uuid_utils-0.16.0-cp313-cp313-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (6.4 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.0->langgraph)
#   Downloading jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph)
#   Using cached ormsgpack-1.12.2-cp313-cp313-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.9)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph) (2.34.2)
# Collecting websockets>=15.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph)
#   Downloading websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph)
#   Using cached zstandard-0.25.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.13.0)
# Requirement already satisfied: certifi in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.13)
# Requirement already satisfied: h11>=0.16 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langgraph) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/amiteshsinha/Training/ai_labs/2026_4_genAI_Lab/.venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.0->langgraph) (2.7.0)
# Downloading langgraph-1.2.2-py3-none-any.whl (236 kB)
# Downloading langchain_core-1.4.0-py3-none-any.whl (548 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.1/548.1 kB 12.9 MB/s eta 0:00:00
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.3.15-py3-none-any.whl (98 kB)
# Downloading langsmith-0.8.7-py3-none-any.whl (402 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.16.0-cp313-cp313-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (563 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.2/563.2 kB 25.6 MB/s eta 0:00:00
# Downloading jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Downloading langchain_protocol-0.0.16-py3-none-any.whl (7.0 kB)
# Using cached ormsgpack-1.12.2-cp313-cp313-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (378 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl (175 kB)
# Downloading xxhash-3.7.0-cp313-cp313-macosx_11_0_arm64.whl (30 kB)
# Using cached zstandard-0.25.0-cp313-cp313-macosx_11_0_arm64.whl (640 kB)
# Installing collected packages: zstandard, xxhash, websockets, uuid-utils, tenacity, ormsgpack, langchain-protocol, jsonpointer, requests-toolbelt, jsonpatch, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [langgraph]237m━━ 15/16 [langgraph]checkpoint]
# Successfully installed jsonpatch-1.33 jsonpointer-3.1.1 langchain-core-1.4.0 langchain-protocol-0.0.16 langgraph-1.2.2 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.3.15 langsmith-0.8.7 ormsgpack-1.12.2 requests-toolbelt-1.0.0 tenacity-9.1.4 uuid-utils-0.16.0 websockets-16.0 xxhash-3.7.0 zstandard-0.25.0
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Build a simple sequential graph using Langgraph

# %%
from langgraph.graph import StateGraph, START, END

# %%
def node_a_agent(dict):
    # Simulate some processing
    # Do something useful here
    print("Agent A is running")
    return {}

def node_b_agent(dict):
    # Simulate some processing
    # Do something useful here
    print("Agent B is running")
    return {}

builder = StateGraph(dict)

builder.add_node("Agent_A", node_a_agent)
builder.add_node("Agent_B", node_b_agent)

name_agent_a = "Agent_A"
name_agent_b = "Agent_B"
builder.add_edge(START, "Agent_A")
builder.add_edge("Agent_A", "Agent_B")
builder.add_edge("Agent_B", END)


graph = builder.compile()

# %%
# %pip install grandalf
# Out:
# Collecting grandalf
#   Using cached grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting pyparsing (from grandalf)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Using cached grandalf-0.8-py3-none-any.whl (41 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, grandalf
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [grandalf]
# Successfully installed grandalf-0.8 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# --- Display as ASCII ---
print(graph.get_graph().draw_ascii())
# Out:
# +-----------+
# | __start__ |
# +-----------+
#       *
#       *
#       *
#  +---------+
#  | Agent_A |
#  +---------+
#       *
#       *
#       *
#  +---------+
#  | Agent_B |
#  +---------+
#       *
#       *
#       *
#  +---------+
#  | __end__ |
#  +---------+

# %%
# Invoke the graph with an empty initial state
initial_state = {}
graph.invoke(initial_state)
