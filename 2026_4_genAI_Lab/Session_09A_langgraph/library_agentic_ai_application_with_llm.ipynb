# %%
from typing import TypedDict, Optional
from langgraph.graph import StateGraph, START, END

from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv(override=True, dotenv_path="../.env.local")
my_api_key = os.getenv("OPENAI_API_KEY")
print (f'Key is {my_api_key[:10]}...')
# Out:
# Key is sk-proj-5I...

# %%
client = OpenAI(api_key=my_api_key)


# --- Shared State ---
class LibraryState(TypedDict):
    question: Optional[str]
    faq_flag: Optional[bool]
    faq_answer: Optional[str]
    checkout_flag: Optional[bool]
    checkout_answer: Optional[str]
    final_answer: Optional[str]


def ClassifierAgent(state: LibraryState):
    print(f"ClassifierAgent Initial state: {state}")

    question = state["question"]

    messages = [
        {
            "role": "system",
            "content": (
                "You are a classifier agent in a library system.\n"
                "Determine whether the question involves:\n"
                "1. Library FAQs (hours, rules, membership)\n"
                "2. Book availability or checkout\n\n"
                "Return ONLY valid JSON:\n"
                "{\n"
                '  "faq_flag": true | false,\n'
                '  "checkout_flag": true | false\n'
                "}"
            )
        },
        {"role": "user", "content": question}
    ]

    response = client.chat.completions.create(
        model="gpt-4.1-nano",
        messages=messages,
    )

    import json
    parsed = json.loads(response.choices[0].message.content)

    return {
        "faq_flag": bool(parsed.get("faq_flag", False)),
        "checkout_flag": bool(parsed.get("checkout_flag", False)),
    }


def FAQAgent(state: LibraryState):
    print(f"FAQAgent state: {state}")

    if not state.get("faq_flag"):
        return {"faq_answer": None}

    messages = [
        {"role": "system", "content": "You answer library FAQ questions."},
        {"role": "user", "content": state["question"]}
    ]

    response = client.chat.completions.create(
        model="gpt-4.1-nano",
        messages=messages,
    )

    return {
        "faq_answer": response.choices[0].message.content
    }



def CheckoutAgent(state: LibraryState):
    print(f"CheckoutAgent state: {state}")

    if not state.get("checkout_flag"):
        return {"checkout_answer": None}

    # Connect to library API and fetch real data here. 
    # Once checkout is complete, call LLM to generate a response based 
    # on the API result.
    
    # For demo, we use LLM to generate a response.
    messages = [
        {"role": "system", "content": "You answer questions about book availability and checkout."},
        {"role": "user", "content": state["question"]}
    ]

    response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=messages,
    )

    return {
        "checkout_answer": response.choices[0].message.content
    }


def ResponseAgent(state: LibraryState):
    print(f"ResponseAgent state: {state}")

    faq = state.get("faq_answer")
    checkout = state.get("checkout_answer")

    parts = []
    if faq:
        parts.append(f"FAQ Information:\n{faq}")
    if checkout:
        parts.append(f"Checkout Information:\n{checkout}")

    combined_context = "\n\n".join(parts)

    messages = [
        {
            "role": "system",
            "content": "Combine the information into a helpful response."
        },
        {
            "role": "user",
            "content": f"Question: {state['question']}\n\n{combined_context}"
        }
    ]

    response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=messages,
    )

    return {
        "final_answer": response.choices[0].message.content
    }


# --- Build the Graph ---
builder = StateGraph(LibraryState)
builder.add_node("ClassifierAgent", ClassifierAgent)
builder.add_node("FAQAgent", FAQAgent)
builder.add_node("CheckoutAgent", CheckoutAgent)
builder.add_node("ResponseAgent", ResponseAgent)

builder.add_edge(START, "ClassifierAgent")
builder.add_edge("ClassifierAgent", "FAQAgent")
builder.add_edge("ClassifierAgent", "CheckoutAgent")
builder.add_edge("FAQAgent", "ResponseAgent")
builder.add_edge("CheckoutAgent", "ResponseAgent")
builder.add_edge("ResponseAgent", END)

graph = builder.compile()

# %%
user_input = input("Ask a question about the library: ")
result = graph.invoke({"question": user_input})
print("\n--- Final Answer ---")
print(result["final_answer"])
# Out:
# ClassifierAgent Initial state: {'question': 'when can I checkout a book?'}
# CheckoutAgent state: {'question': 'when can I checkout a book?', 'faq_flag': False, 'checkout_flag': True}FAQAgent state: {'question': 'when can I checkout a book?', 'faq_flag': False, 'checkout_flag': True}
#
# ResponseAgent state: {'question': 'when can I checkout a book?', 'faq_flag': False, 'faq_answer': None, 'checkout_flag': True, 'checkout_answer': 'It depends on a few things, but here’s the general idea:\n\n- If the book is available now, you can check it out right away (at the desk or with self-checkout) as long as you have a valid library card in good standing.\n- If the book is currently checked out, you can place a hold. You’ll be notified when it’s returned and ready for pickup (pickup window varies by library).\n- For eBooks/e-audiobooks, you can usually borrow immediately if a license is available; if not, you’ll be placed on a waitlist.\n\nWhat I need to give you a precise answer:\n- Which library you’re using (branch or city)?\n- The title (and author, if you have it) of the book?\n\nIf you share those, I can tell you the book’s current status and how long the loan period would be, plus how to place a hold or check it out.'}
#
# --- Final Answer ---
# Here’s the quick guide, plus what I need to give you a precise answer:
#
# General rules
# - If the book is available now: you can check it out right away (in person at the desk or with self-checkout) as long as your library card is in good standing.
# - If the book is checked out: you can place a hold. You’ll be notified when it’s returned and ready for pickup. Pickup windows vary by library.
# - For eBooks/e-audiobooks: you can usually borrow immediately if a license is available; if not, you’ll be placed on a waitlist.
#
# To give you a precise answer (status, loan period, and how to place a hold)
# - Tell me which library you’re using (branch or city)
# - Tell me the book title (and author if you have it)
#
# If you’d like, I can also walk you through checking the status or placing a hold in your library’s catalog or app.

# %%
# result = graph.invoke({"question": "Is The new best seller available? When does library open?"})
# print("\n--- Final Answer ---")
# print(result["final_answer"])

# %%
# # --- Visualize ---
# print(graph.get_graph().draw_ascii())
# graph.get_graph().draw_png("images/agentic_ai_library.png")
# print("Graph saved as agentic_ai_library.png")

# %%
# --- Run ---
result = graph.invoke({"question": 
                       '''When does Cupertino library open? I would like to check out a book as 
                       well.'''})
print("\n--- Final Answer ---")
print(result["final_answer"])
# Out:
# ClassifierAgent Initial state: {'question': 'When does Cupertino library open? I would like to check out a book as \n                       well.'}
# CheckoutAgent state: {'question': 'When does Cupertino library open? I would like to check out a book as \n                       well.', 'faq_flag': True, 'checkout_flag': True}FAQAgent state: {'question': 'When does Cupertino library open? I would like to check out a book as \n                       well.', 'faq_flag': True, 'checkout_flag': True}
#
# ResponseAgent state: {'question': 'When does Cupertino library open? I would like to check out a book as \n                       well.', 'faq_flag': True, 'faq_answer': "Cupertino Library generally opens at 10:00 AM and closes at 9:00 PM from Monday to Thursday, 10:00 AM to 5:00 PM on Friday to Sunday, and is typically closed on Mondays. However, hours may vary due to holidays or special events. \n\nI recommend checking the official Cupertino Library website or contacting them directly at (408) 394-3500 for the most current hours of operation. Once you're there, you can browse the collection and check out books at the circulation desk. Happy reading!", 'checkout_flag': True, 'checkout_answer': 'I can help with both. Do you want me to look up today’s Cupertino Library hours or a typical schedule for the week?\n\nTo check out a book, you’ll need a Cupertino/SCCLD library card. If you don’t have one, I can help you sign up. A few quick options:\n- Tell me the book you want (title and author) and whether you want a physical copy or an eBook.\n- If you already have a card, share the title and I can check its availability and direct you to the best way to check it out (in person at the desk or with self-checkout).\n- If you don’t know the exact title, I can help you search the catalog by topic, author, or keywords.\n\nWould you like me to fetch today’s hours for Cupertino Library and also check the availability of a specific book? If so, please tell me the book title (and author) and whether you want a physical copy or an eBook.'}
#
# --- Final Answer ---
# Here’s what the FAQ says:
#
# - Typical hours (subject to holidays/events):
#   - Monday–Thursday: 10:00 AM to 9:00 PM
#   - Friday–Sunday: 10:00 AM to 5:00 PM
# - Note: The FAQ also says the library is “typically closed on Mondays,” which contradicts the 10:00–9:00 schedule above. Hours can vary for holidays or special events. To be certain today, please check the official Cupertino Library site or call them at (408) 394-3500.
#
# Would you like me to fetch today’s hours for you, or a weekly schedule?
#
# For checking out a book:
# - You’ll need a Cupertino/SCCLD library card. If you don’t have one, I can help you sign up.
# - To search for a book, tell me:
#   - Title and author (or just topic/keywords if you’re not sure)
#   - Whether you want a physical copy or an eBook
# - If you already know the exact title, I can check its availability and guide you to check it out (in person at the desk or via self-checkout).
#
# Would you like me to:
# 1) fetch today’s hours, and/or
# 2) look up the availability of a specific book? If so, please share the book title (and author) and your preferred format.

# %%
result = graph.invoke({"question": "Is The Hobbit available? When does the library open"})
print("\n--- Final Answer ---")
print(result["final_answer"])
# Out:
# ClassifierAgent Initial state: {'question': 'Is The Hobbit available? When does the library open'}
# CheckoutAgent state: {'question': 'Is The Hobbit available? When does the library open', 'faq_flag': False, 'checkout_flag': True}FAQAgent state: {'question': 'Is The Hobbit available? When does the library open', 'faq_flag': False, 'checkout_flag': True}
#
# ResponseAgent state: {'question': 'Is The Hobbit available? When does the library open', 'faq_flag': False, 'faq_answer': None, 'checkout_flag': True, 'checkout_answer': 'I can help, but I need a bit more info:\n\n- Do you want a physical copy or a digital copy (eBook/audiobook)?\n- Which library location or branch should I check (or your library system/city)?\n- For hours: which branch should I pull the current opening times for?\n\nIf you share your branch or city, I can tell you real-time availability for The Hobbit and the exact opening hours, and I can guide you on placing a hold or checking out if it’s available.'}
#
# --- Final Answer ---
# I can help, but I need a bit more info:
#
# - Do you want a physical copy or a digital copy (eBook/audiobook)?
# - Which library location or branch should I check (or your library system/city)?
# - For hours: which branch should I pull the current opening times for?
#
# If you share your branch or city, I can tell you real-time availability for The Hobbit and the exact opening hours, and I can guide you on placing a hold or checking out if it’s available.
#
# Tip: If you’d rather check yourself right now, you can search your library’s online catalog for The Hobbit, filter by your location, and you’ll see availability and an option to place a hold or check out a digital copy.
