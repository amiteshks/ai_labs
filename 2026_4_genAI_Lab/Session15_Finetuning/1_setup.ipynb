# %%
# %pip install --upgrade pip

# %%
# %pip install mlx mlx-lm huggingface_hub transformers datasets

# %%
import mlx
import mlx.core as mx
import mlx_lm

print("MLX imported successfully!")
print("MLX-LM imported successfully!")

# %%
#Try this on the terminal
# hf auth login

# %%
MODEL = "mlx-community/Llama-3.2-1B-Instruct-4bit"

# %%
from mlx_lm import load

model, tokenizer = load(MODEL)

# %%
print(type(model))
print(type(tokenizer))

# %%
from mlx_lm import generate

prompt = """
Write a short commercial real estate listing
for a 10,000 SF office building in Austin.
"""

response = generate(
    model,
    tokenizer,
    prompt=prompt,
    max_tokens=200
)

print(response)
